# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
import pandas as pd 
from sklearn.pipeline import Pipeline

# %%
d = {'Height': [150,152,154,157,160,162,168,170,173,178,180]}
df = pd.DataFrame(d)
df
# Out:
#     Height
# 0      150
# 1      152
# 2      154
# 3      157
# 4      160
# 5      162
# 6      168
# 7      170
# 8      173
# 9      178
# 10     180

# %%
model = KMeans(n_clusters=3)
model.fit_predict(df)
# Out:
# array([2, 2, 2, 1, 1, 1, 0, 0, 0, 0, 0], dtype=int32)

# %%
label = model.labels_
label
# Out:
# array([2, 2, 2, 1, 1, 1, 0, 0, 0, 0, 0], dtype=int32)

# %%
centroid = model.cluster_centers_
centroid
# Out:
# array([[173.8       ],
#        [159.66666667],
#        [152.        ]])

# %%
for i in range(len(df)):
    print(f"Height{i}--> group:{label[i]}")
# Out:
# Height0--> group:2
# Height1--> group:2
# Height2--> group:2
# Height3--> group:1
# Height4--> group:1
# Height5--> group:1
# Height6--> group:0
# Height7--> group:0
# Height8--> group:0
# Height9--> group:0
# Height10--> group:0
