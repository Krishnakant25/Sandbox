# %%
import cv2

# %%
image = cv2.imread(r"D:\Practice_Code\mountain .jpg")

# %%
if image is None:
    print("No Image")
else:
    print("image")
# Out:
# image

# %%
cv2.imshow("Image Window",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image_new = image + 30
cv2.imwrite("./output.jpg", image_new)
# Out:
# True
