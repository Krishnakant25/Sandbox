# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_excel(r'D:\python assignments\Machine.xlsx')
df.head()
# Out:
#   Marks  Extra_curicular Result
# 0   <50                1   Fail
# 1   <50                0   Pass
# 2  >=50                0   Pass
# 3  >=50                1   Fail
# 4   <50                1   Fail

# %%
X = df.drop('Result', axis=1)
y = df['Result']

# %%
le = LabelEncoder()
x_train_enc = le.fit_transform(df['Marks'])
x_train_enc
# Out:
# array([0, 0, 2, 2, 0, 2, 1])

# %%
new = le.fit_transform(['100'])
new
# Out:
# array([0])
