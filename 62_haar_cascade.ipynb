# %%
import cv2

# %%
# Face Detection
cam = cv2.VideoCapture(0)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

try:
    while True:
        ret, frame = cam.read()

        if not ret:
            print("Failed to grab frame. Is another app using the camera?")
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

        for (x,y,w,h) in faces:
            cv2.rectangle(frame, (x,y), (x+w, y+h), (255, 0, 0), 2)
            cv2.putText(frame, "Face Detected", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2, cv2.LINE_AA)

        cv2.imshow('Camera', frame)

        # Press 'q' to quit (Ensure the popup window is actively selected!)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

finally:
    # This runs no matter what, even if you click "Interrupt" in Jupyter!
    cam.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       6 try:
#       7     while True:
# ----> 8         ret, frame = cam.read()
#      10         if not ret:
#      11             print("Failed to grab frame. Is another app using the camera?")
#
# KeyboardInterrupt:

# %%
# face + eye + mouth
cam = cv2.VideoCapture(0)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
mouth_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_smile.xml')

try:
    while True:
        ret, frame = cam.read()

        if not ret:
            print("Failed to grab frame. Is another app using the camera?")
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

        for (x,y,w,h) in faces:
            cv2.rectangle(frame, (x,y), (x+w, y+h), (255, 0, 0), 2)
            cv2.putText(frame, "Face Detected", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2, cv2.LINE_AA)

            roi_gray = gray[y:y+h, x:x+w]
            roi_color = frame[y:y+h, x:x+w]

            eyes = eye_cascade.detectMultiScale(roi_gray, scaleFactor=1.3, minNeighbors=5)
            mouths = mouth_cascade.detectMultiScale(roi_gray, scaleFactor=1.8, minNeighbors=20)

            for (ex,ey, ew, eh) in eyes:
                cv2.rectangle(frame, (x+ex,y+ey), (x+ex+ew, y+ey+eh), (255, 0, 0), 2)
                cv2.putText(frame, "Eye", (x+ex,(y+ey) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2, cv2.LINE_AA)
            
            for (mx,my, mw, mh) in mouths:
                cv2.rectangle(frame, (x+mx,y+my), (x+mx+mw, y+my+mh), (0, 0, 255), 2)
                cv2.putText(frame, "Mouth", (x+mx,(y+my) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,255), 2, cv2.LINE_AA)

        cv2.imshow('Camera', frame)

        # Press 'q' to quit (Ensure the popup window is actively selected!)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

finally:
    # This runs no matter what, even if you click "Interrupt" in Jupyter!
    cam.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 17
#      14     break
#      16 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# ---> 17 faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)
#      19 for (x,y,w,h) in faces:
#      20     cv2.rectangle(frame, (x,y), (x+w, y+h), (255, 0, 0), 2)
#
# KeyboardInterrupt:
