# %%
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
df = pd.read_csv(r'D:\python assignments\loan_approval_dataset.csv')
df.head()
# Out:
#    Age  Salary  Credit_Score  Loan_Amount  Loan_Term Employment_Status  \
# 0   56  136748           584        38209  36 months          Employed
# 1   46   25287           815        27424  24 months     Self-Employed
# 2   32  146593           398        42396  12 months        Unemployed
# 3   60   54387           696        11370  24 months        Unemployed
# 4   25   28512           788        14528  12 months          Employed
#
#   Residence_Type Previous_Default Loan_Approved
# 0          Owned              Yes           Yes
# 1         Rented               No           Yes
# 2         Rented              Yes           Yes
# 3          Owned               No            No
# 4          Owned               No            No

# %%
x = df.drop("Loan_Approved", axis=1)
y = df["Loan_Approved"]

# %%
num_col = x.select_dtypes(exclude='object').columns
cat_col = x.select_dtypes(include='object').columns

# %%
scale = StandardScaler()
ohe = OneHotEncoder(sparse_output=False)

# %%
scaled = scale.fit_transform(x[num_col])
converted = ohe.fit_transform(x[cat_col])

# %%
x_final = np.concatenate([scaled,converted], axis=1)

# %%
x_train,x_test, y_train, y_test = train_test_split(x_final,y, test_size=0.2, random_state=42)

# %%
model = DecisionTreeClassifier(max_depth=3, criterion='gini')

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred = model.predict(x_test)

# %%
plt.figure(figsize=(10,12))
plot_tree(model, filled=True, feature_names=x_test, fontsize=5)
plt.show()
